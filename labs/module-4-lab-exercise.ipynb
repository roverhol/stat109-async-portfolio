# %% [markdown]
# # Module 4 — Exercise lab (student)
#
# **Submit in Canvas** · Work all four problems after the [demo lab](module-4-lab-demo).
#
# Use plain code (no instructor color markup). Connect each problem to [Project 4](../projects/project-4) design choices.
#
# **Practice bank:** [Synthesis quiz](../quizzes/quiz-m4-synthesis) Section E mirrors these situations.

# %% [markdown]
# ## Problem 1 — Numerical outcome: simulate and test
#
# Two independent groups; numerical outcome.
#
# 1. Set a seed. Simulate two groups with different true means (your choice).
# 2. Compute group summaries (`group_by` + `summarize`).
# 3. Boxplot by group.
# 4. Run `t.test(outcome ~ group, data = df)`.
# 5. Report: decision ($\alpha=0.05$), 95% CI, one-sentence interpretation.

# %%
# Your code

# %% [markdown]
# ## Problem 2 — Binary outcome: simulate and test
#
# Two independent groups; binary outcome.
#
# 1. Simulate with `rbinom()` for two groups with different true proportions.
# 2. Summarize proportions by group.
# 3. 100% stacked bar plot.
# 4. Run `prop.test(c(x1, x2), c(n1, n2))`.
# 5. Decision and one-sentence interpretation.

# %%
# Your code

# %% [markdown]
# ## Problem 3 — Validate under the null
#
# Run 500 simulations with no true difference ($\mu_1 = \mu_2$).
#
# 1. Collect p-values in a vector.
# 2. Compute the empirical Type I error rate.
# 3. Histogram of p-values — comment on whether it looks uniform.

# %%
# Your code

# %% [markdown]
# ## Problem 4 — Connect to Project 4
#
# Describe your **Project 4 simulation plan**:
#
# 1. What is your EV (explanatory variable)? RV (response)?
# 2. Is the outcome numerical or binary?
# 3. Which R function will you use for the two-group test?
# 4. What true parameter values will you simulate from?
#
# Write your answers below, then add starter code.

# %%
# Your code

# %% [markdown]
# # Module 3 — Demo lab (legacy combined link)
#
# This notebook has been split into two demos:
#
# 1. [Demo 1 — R tools](module-3-lab-demo-tools.ipynb): `count`, `group_by`/`summarize`, geoms, `cor()`, `read_csv`
# 2. [Demo 2 — worked examples](module-3-lab-demo-worked.ipynb): five full EDA problems on `penguins`

# %% [markdown]
# # Module 1 — Exercise lab (student)
#
# **Submit in Canvas** · Plain code · Prompts were demo'd in [main demo](module-1-lab-demo) and [conditional demo](module-1-lab-demo-conditional).
#
# **R basics:** [Module 0 exercise lab](module-0-lab-exercise).
#
# | Part | Topic | Demo |
# |------|-------|------|
# | I | Data structures & simulation | [Section B](module-1-lab-demo) |
# | II | Conditional simulation | [Conditional demo](module-1-lab-demo-conditional) |
# | III | Binomial functions & plots | [Section C](module-1-lab-demo) |
#
# **Project precheck** → [Project 1 milestone](../projects/project-1-milestone.ipynb) — not this notebook.

# %% [markdown]
# ## Part I — Data structures & simulation

# %%
[1] "numeric"

# %% [markdown]
# **Your task:** Store `3.5` in `x` and check its class.

# %%
# Solution

# %% [markdown]
# ------------------------------------------------------------------------
#
# ### 1.2 Integer vs numeric
#
# **Goal output**

# %%
[1] "integer"

# %% [markdown]
# **Your task:** Store an integer in `y` and check its class.

# %%
# Solution

# %% [markdown]
# ------------------------------------------------------------------------
#
# ### 1.3 Character (string) values use quotes
#
# **Goal output**

# %%
[1] "character"

# %% [markdown]
# **Your task:** Store `"hello"` in `w` and check its class.

# %%
# Solution

# %% [markdown]
# ------------------------------------------------------------------------
#
# ### 1.4 Logical values come from comparisons
#
# **Goal output**

# %%
[1] TRUE

# %% [markdown]
# **Your task:** Write a comparison that evaluates to `TRUE`.

# %%
# Solution (one possible answer)

# %% [markdown]
# ------------------------------------------------------------------------
#
# ### 1.5 Converting (coercing) types
#
# Sometimes you have `"7"` (text) but you need `7` (a number).
#
# **Goal output**

# %%
[1] 7

# %% [markdown]
# **Your task:** Convert the character `"7"` into a numeric value.

# %%
# Solution

# %% [markdown]
# **Note:** `as.numeric("seven")` gives `NA` (missing) because R can’t turn the word “seven” into a number.
#
# ------------------------------------------------------------------------
#
# ## Part 2 — Vectors (the basic data structure)
#
# ### 2.1 Create a numeric vector
#
# **Goal output**

# %%
[1] 2 4 6 8 10

# %% [markdown]
# **Your task:** Create a vector named `numbers` containing `2, 4, 6, 8, 10`.

# %%
# Solution

# %% [markdown]
# ------------------------------------------------------------------------
#
# ### 2.2 Create a character vector
#
# **Goal output**

# %%
[1] "H" "T" "H" "H" "T"

# %% [markdown]
# **Your task:** Create a vector named `flips` containing `"H", "T", "H", "H", "T"`.

# %%
# Solution

# %% [markdown]
# ------------------------------------------------------------------------
#
# ### 2.3 Sequences and repetition
#
# **Goal output**

# %%
[1] 1 2 3 4 5 6

# %% [markdown]
# **Your task:** Create the sequence 1 through 6 without typing every number.

# %%
# Solution

# %% [markdown]
# ------------------------------------------------------------------------
#
# ### 2.3b Check the “size” of a vector with `length()`
#
# Many errors come from combining objects of different sizes. For vectors, the size is the **length** (how many entries).
#
# **Goal output**

# %%
[1] 5

# %% [markdown]
# **Your task:** Check the length of `numbers <- c(2, 4, 6, 8, 10)`.

# %%
# Solution
numbers <- c(2, 4, 6, 8, 10)

# %% [markdown]
# ------------------------------------------------------------------------
#
# ### 2.3c Combine two vectors of the same length (element-by-element)
#
# When two vectors have the same length, `+` and `==` work **element-by-element**.
#
# **Goal output**

# %%
[1] 11 22 33

# %% [markdown]
# **Your task:** Add the vectors `a <- c(1, 2, 3)` and `b <- c(10, 20, 30)`.

# %%
# Solution
a <- c(1, 2, 3)
b <- c(10, 20, 30)

# %% [markdown]
# **Diagnostic tip:** If `length(a) != length(b)`, stop and fix that first.
#
# ------------------------------------------------------------------------
#
# ### 2.3d Add or multiply a vector by a single number (a “scalar”)
#
# Adding or multiplying by a single number applies to **every entry** of the vector.
#
# **Goal output**

# %%
[1] 7 9 11

# %% [markdown]
# **Your task:** Start with `v <- c(2, 4, 6)` and create `v_plus_5 <- v + 5`.

# %%
# Solution
v <- c(2, 4, 6)

# %% [markdown]
# **Also useful:**

# %%
# multiply every entry by 2
# Solution
v <- c(2, 4, 6)

# %% [markdown]
# ------------------------------------------------------------------------
#
# ### 2.4 Indexing and subsetting
#
# Run the code below. What does `numbers[3]` return?

# %%
numbers <- c(2, 4, 6, 8, 10)
numbers[3]

# %% [markdown]
# **Solution:** `numbers[3]` returns ...
#
# ------------------------------------------------------------------------
#
# ### 2.4b Bracketing practice (vectors)
#
# The brackets `[...]` are one of the most important skills in R. Here are common patterns you’ll use all semester.
#
# Use this setup:

# %%
numbers <- c(2, 4, 6, 8, 10)

# %% [markdown]
# **2.4b(i) Grab multiple positions**
#
# **Goal output**

# %%
[1] 2 6 10

# %% [markdown]
# **Your task:** Use brackets to grab the 1st, 3rd, and 5th entries.

# %%
# Solution

# %% [markdown]
# ------------------------------------------------------------------------
#
# **2.4b(ii) Grab a range of positions**
#
# **Goal output**

# %%
[1] 4 6 8

# %% [markdown]
# **Your task:** Use brackets to grab the 2nd through 4th entries.

# %%
# Solution

# %% [markdown]
# ------------------------------------------------------------------------
#
# **2.4b(iii) Drop a position (negative index)**
#
# **Goal output**

# %%
[1] 2 4 8 10

# %% [markdown]
# **Your task:** Use brackets to return everything **except** the 3rd entry.

# %%
# Solution

# %% [markdown]
# ------------------------------------------------------------------------
#
# **2.4b(iv) Use a logical vector inside brackets**
#
# **Goal output**

# %%
[1] 6 8 10

# %% [markdown]
# **Your task:** Use a condition inside brackets to keep values greater than 5.

# %%
# Solution

# %% [markdown]
# ------------------------------------------------------------------------
#
# ### 2.5 Logical conditions create TRUE/FALSE vectors
#
# **Goal output**

# %%
[1] FALSE FALSE  TRUE  TRUE  TRUE

# %% [markdown]
# **Your task:** Create a logical vector that checks which entries of `numbers` are greater than 5.

# %%
# Solution
numbers <- c(2, 4, 6, 8, 10)

# %% [markdown]
# ------------------------------------------------------------------------
#
# ### 2.6 Logical subsetting (filtering)
#
# **Goal output**

# %%
[1] 6 8 10

# %% [markdown]
# **Your task:** Use logical subsetting to keep only the values in `numbers` that are greater than 5.

# %%
# Solution
numbers <- c(2, 4, 6, 8, 10)

# %% [markdown]
# ------------------------------------------------------------------------
#
# ## Part 3 — Matrices (2D numeric data)
#
# Matrices are a 2D extension of vectors. The key idea is the same brackets, but now you give **row** and **column**: `m[row, col]`.
#
# ### 3.1 Create a matrix and index it
#
# **Goal output**

# %%
     [,1] [,2] [,3]
[1,]    1    3    5
[2,]    2    4    6

# %% [markdown]
# **Your task:** Create a 2x3 matrix with the numbers 1 through 6 filled **by column**.

# %%
# Solution
m = # your matrix creation code here
m

# %% [markdown]
# ------------------------------------------------------------------------
#
# ### 3.1b Check the “size” of a matrix with `dim()`, `nrow()`, `ncol()`
#
# For matrices, the size is **rows and columns**.
#
# **Goal output**

# %%
[1] 2 3

# %% [markdown]
# **Your task:** Check the dimensions of `m`.

# %%
# Solution

# %% [markdown]
# **Also useful (one number at a time):**

# %%
nrow(m)
ncol(m)

# %% [markdown]
# ------------------------------------------------------------------------
#
# ### 3.1c Combine two matrices of the same size (element-by-element)
#
# If two matrices have the same dimensions, `+` and `==` work element-by-element (this is **not** matrix multiplication).
#
# **Goal output**

# %%
     [,1] [,2] [,3]
[1,]    2    6   10
[2,]    4    8   12

# %% [markdown]
# **Your task:** Create `m2 <- m` and compute `m + m2`.

# %%
# Solution

# %% [markdown]
# **Diagnostic tip:** If `dim(m) != dim(m2)`, you cannot add them safely.
#
# ------------------------------------------------------------------------
#
# ### 3.1d Add or multiply a matrix by a single number (a “scalar”)
#
# Just like vectors, a single number applies to every entry.
#
# **Goal output**

# %%
     [,1] [,2] [,3]
[1,]    6    8   10
[2,]    7    9   11

# %% [markdown]
# **Your task:** Compute `m + 5`.

# %%
# Solution

# %% [markdown]
# **Also useful:**

# %%
2 * m
m * 2

# %% [markdown]
# ------------------------------------------------------------------------
#
# ### 3.2 Extract a row and a column
#
# **Goal output**

# %%
[1] 1 3 5

# %% [markdown]
# **Your task:** Extract the first row of `m`.

# %%
# Solution

# %% [markdown]
# ------------------------------------------------------------------------
#
# ### 3.3 Bracketing practice (matrices)
#
# Use this setup (same `m` as above):

# %%
m <- matrix(1:6, nrow = 2, ncol = 3)
m

# %% [markdown]
# **3.3(i) One entry (row, column)**
#
# **Goal output**

# %%
[1] 4

# %% [markdown]
# **Your task:** Extract the entry in row 2, column 2.

# %%
# Solution

# %% [markdown]
# ------------------------------------------------------------------------
#
# **3.3(ii) One column**
#
# **Goal output**

# %%
[1] 3 4

# %% [markdown]
# **Your task:** Extract the 2nd column of `m`.

# %%
# Solution

# %% [markdown]
# ------------------------------------------------------------------------
#
# **3.3(iii) A submatrix (multiple rows and columns)**
#
# **Goal output**

# %%
     [,1] [,2]
[1,]    1    3
[2,]    2    4

# %% [markdown]
# **Your task:** Extract rows 1:2 and columns 1:2.

# %%
# Solution

# %% [markdown]
# ------------------------------------------------------------------------
#
# ## Part 4 — For loops (repeat a process and store results)
#
# ### 4.0 Anatomy of a `for` loop (what each piece means)
#
# A `for` loop repeats the same steps many times. Here is the basic “shape”:

# %%
for (i in 1:n) {
  # code to repeat goes here
}

# %% [markdown]
# What the parts mean:
#
# - `for (...) { ... }`: tells R “repeat what’s inside the braces `{}`”.
# - `i`: the **index variable** (a name you choose). It takes on values one-at-a-time.
# - `in 1:n`: the **sequence** of values `i` will go through (here: 1, 2, 3, ..., n).
# - `{` and `}`: the braces mark the **body** of the loop (the code that repeats).
#
# Most of the time we also:
#
# - **Pre-allocate storage** (make an empty vector first) so we have a place to save results.
# - **Store one result each time** using indexing like `results[i] <- ...`.
#
# #### Making “empty placeholders” (pre-allocation)
#
# When you know you will store **n numbers**, it helps to create the container first:
#
# - `numeric(n)` makes a vector of length `n` filled with zeros (a placeholder for numbers).
# - `logical(n)` makes a vector of length `n` filled with `FALSE`.
# - `character(n)` makes a vector of length `n` filled with `""` (empty strings).
#
# For matrices, you can do the same idea in 2D:
#
# - `matrix(NA, nrow = r, ncol = c)` makes an `r` by `c` placeholder matrix.
#
# ### 4.1 A simple for loop over 1 to 5
#
# **Goal output**

# %%
[1]  1  4  9 16 25

# %% [markdown]
# **Your task:** Use a `for` loop to fill a vector with the squares of 1 through 5.

# %%
# Solution
results <- numeric(5) # storage: 5 empty slots
for (i in 1:5) {
  # i takes values 1, 2, 3, 4, 5
  results[i] <-#  fill in this bit
}
results
# Out:
# [1]  1  4  9 16 25

# %% [markdown]
# ------------------------------------------------------------------------
#
# ### 4.2 Loop over the entries of a vector
#
# **Goal output**

# %%
[1] 3 5 7 9

# %% [markdown]
# **Your task:** Using a `for` loop, add 1 to each entry of `c(2, 4, 6, 8)` and store the result.

# %%
# Solution
v <- c(2, 4, 6, 8)
v_plus_one <- numeric(length(v))
for (i in 1:length(v)) {
  # i runs over positions 1, 2, 3, 4
  v_plus_one[i] <- # fill in this bit
}
v_plus_one

# %% [markdown]
# ------------------------------------------------------------------------
#
# ### 4.3 Nested loops (optional extension)
#
# **Optional / not required for completion credit.** If students finish early, this is a good stretch problem.
#
# **Goal output**

# %%
     [,1] [,2] [,3]
[1,]    1    2    3
[2,]    2    4    6
[3,]    3    6    9

# %% [markdown]
# **Your task:** Use nested loops to create a 3x3 multiplication table where entry $(i,j)$ is $i \times j$.

# %%
# Solution
tab <- matrix(NA, nrow = 3, ncol = 3)
for (i in 1:3) {
  for (j in 1:3) {
    tab[i, j] <- i * j
  }
}
tab

# %% [markdown]
# ------------------------------------------------------------------------
#
# ## Part 5 — Probability and simulation (equally likely sample spaces)
#
# Key simulation idea for easy grading:
#
# - Make an **event** into a TRUE/FALSE statement (e.g., “roll is even”).
# - The **estimated probability** is just the **proportion of TRUE values**:
#   - in R: `mean(event_is_true)` works because `TRUE` counts as 1 and `FALSE` counts as 0.
#
# ### 5.1 Equally likely outcomes: one fair die
#
# Let $S = \{1,2,3,4,5,6\}$ be the sample space for a fair die roll (all outcomes equally likely).
#
# **New operator:** `%in%` means “is this value in this set/vector?”
#
# - `x == 2` checks “is x equal to 2?”
# - `x %in% c(2, 4, 6)` checks “is x one of 2, 4, or 6?”
#
# For vectors, `%in%` works element-by-element and returns a TRUE/FALSE vector (just like `==` did in Lab 1).
#
# **Your task:**
# - Simulate 10,000 fair die rolls.
# - Estimate $P(\text{roll is even})$.

# %%
# Solution
set.seed(109)

n <- 10000
rolls <- sample(1:6, size = n, replace = TRUE)
# replace = TRUE means outcomes can repeat (like real die rolls)

p_even <- # fill in this bit
p_even

# %% [markdown]
# **Check (theory):** The even outcomes are {2,4,6}, so $P(\text{even}) = 3/6 = 0.5$.
#
# ------------------------------------------------------------------------
#
# ### 5.2 Two fair dice: probability the sum is 7
#
# **Your task:**
# - Simulate 50,000 pairs of fair die rolls.
# - Estimate $P(\text{sum} = 7)$.

# %%
# Solution
set.seed(109)

n <- 50000
# sample(..., size = n, replace = TRUE) gives n independent rolls
d1 <- sample(1:6, size = n, replace = TRUE)
d2 <- sample(1:6, size = n, replace = TRUE)

sums <- d1 + d2
p_sum7 <- # fill in this bit
p_sum7

# %% [markdown]
# **Check (theory idea):** There are 36 equally likely ordered pairs $(d1,d2)$. Six of them sum to 7: (1,6), (2,5), (3,4), (4,3), (5,2), (6,1), so $P(\text{sum}=7) = 6/36 = 1/6$.
#
# ------------------------------------------------------------------------
#
# ### 5.3 Using a for loop to simulate many trials
#
# **Your task:** Repeat the “sum of two dice” experiment using a `for` loop that stores each sum in a vector, then estimate $P(\text{sum}=7)$ using `mean()`.

# %%
# Solution
set.seed(109)

n <- 20000
sums <- numeric(n)

for (i in 1:n) {
  # fill in this bit
}

mean(sums == 7)

# %% [markdown]
# ------------------------------------------------------------------------
#
# ## Part 6 — Reflection (to submit in Canvas)
#
# Write \~200–300 words total answering the prompts below.
#
# 1.  What’s the difference between a **vector** and a **matrix**? Give one sentence for each.\
# 2.  What bit of code was the hardest to figure out for you?
# 3.  In your own words, how does simulation connect to probability when outcomes are “equally likely”?
# 4. Were there bits of code you couldn't figure out in this lab?

# %% [markdown]
# ## Part II — Conditional simulation

# %% [markdown]
# ## Part 1 — Balls in a bag (drawing without replacement)
#
# A bag contains **3 red** and **3 white** balls. Two balls are drawn **one at a time** without replacement between draws.

# %% [markdown]
# ### 1.1 Setup: simulate 10 draws
#
# Simulate **10** sets of two draws. Use `"R"` and `"W"`. Store **1** in `successes[k]` when the first draw is white and the second is red (W then R).

# %% [markdown]
# ### 1.2 Explain `rep()` and `balls`
#
# In a markdown cell (double-click to edit), describe what `balls` contains. How would you change the code for **5 red** and **2 white**?

# %% [markdown]
# ### 1.3 Explain the `if` condition
#
# What does the `if` condition check? When is a success recorded?

# %% [markdown]
# ### 1.4 Which replicates were successes?
#
# Use `which()` to list replicate numbers where `successes == 1`.

# %% [markdown]
# ### 1.5 Estimate probability with 10,000 replicates
#
# Set `replicates <- 10000`, re-run the simulation, and estimate $P(\text{white first and red second})$ with `mean(successes)`.

# %% [markdown]
# ### 1.6 Exactly one red ball
#
# Modify the `if` condition to estimate $P(\text{exactly one red})$ — (R then W) **or** (W then R). Use `|` for **or**.

# %% [markdown]
# ## Part 2 — Population with conditional structure
#
# ~20% of **children** and ~3% of **adults** like gummy vitamins. Assume 50–50 child vs adult.
#
# Let `child = 1` mean child, `gummy = 1` mean likes gummies.
#
# Estimate $P(C \text{ and } G)$ and $P(G)$ from a simulated population of **10,000**.

# %% [markdown]
# ### 2.1 Simulate 10,000 people

# %% [markdown]
# ### 2.2 Estimate $P(C \text{ and } G)$ and $P(G)$

# %% [markdown]
# ## Part 3 — Diagnostic test
#
# Prevalence $P(D) = 0.01$. Sensitivity $P(\text{positive} \mid D) = 0.95$. Specificity $P(\text{negative} \mid \text{no } D) = 0.90$.
#
# Simulate **10,000** people. Estimate $P(D \mid \text{positive})$.

# %% [markdown]
# ## Part 4 — Reflection (submit in Canvas)
#
# Write 2–3 sentences: What did you learn about R and conditional probability? What code was hardest?

# %% [markdown]
# ## Part III — Binomial functions & plots

# %% [markdown]
# ## Setup
#
# **Desired output:** Load packages we’ll use (plotting included) and set a seed.

# %%
library(tidyverse)
set.seed(109)

# %% [markdown]
# ## 1) Factorials in R
#
# **Desired output:** Compute \(6!\) and get `720`. Show two ways: `factorial()` and `prod()`.

# %% [markdown]
# ## 2) Permutations
#
# There are 10 students and we choose 5 **in order** (order matters).
#
# **Desired output:** Compute ${}_{10}P_5$.

# %% [markdown]
# ## 3) Combinations
#
# There are 10 students and we choose 5 **without order** (order does not matter).
#
# **Desired output:** Compute ${}_{10}C_5$ using `choose()` and factorials.

# %% [markdown]
# ## 4) Binomial model: identify \(n\), \(p\), \(x\)
#
# A basketball player takes 12 free throws. Each is made with probability 0.70.
#
# Let \(X\) = number made.
#
# **Desired output:** Identify `n`, `p`, `x` and compute `P(X = 9)` using `dbinom()`.

# %%
n <- 12
p <- 0.70
x <- 9

# %% [markdown]
# ## 5) Binomial cumulative probabilities with `pbinom()`
#
# Using `n = 12`, `p = 0.70`:
#
# **Desired output:**
# 1. `P(X <= 9)`
# 2. `P(X >= 10)`
# 3. Show the correct cutoff for the right tail.

# %%
n <- 12
p <- 0.70

# %% [markdown]
# ## 6) Simulating a binomial random variable with `rbinom()`
#
# For `n = 12`, `p = 0.70`:
#
# **Desired output:** Simulate 10,000 repetitions and estimate `P(X >= 10)`. Check with `pbinom()`.

# %%
n <- 12
p <- 0.70
reps <- 10000

# %% [markdown]
# ## 7) Coin toss simulation with a `for` loop + `sample()`
#
# Simulate 20 fair coin tosses many times and estimate `P(X >= 15)`.
#
# **Desired output:** Use a `for` loop + `sample(c("H","T"))` and compare to `pbinom()`.

# %%
n <- 20
reps <- 5000
x <- vector("numeric", reps)

set.seed(109)
for(i in 1:reps){
  tosses <- # fill in
  x[i] <-  # fill in
}

mean(x >= 15)
pbinom(14, size = 20, prob = 0.5, lower.tail = FALSE)

# %% [markdown]
# ## 8) Plot: simulated proportions vs `dbinom` as bars (simple ggplot)
#
# Here we use **simple ggplot bars**:
# - Blue bars: simulation proportions via `after_stat(prop)`
# - Red bars: `dbinom` probabilities via `geom_col()`
#
# **Desired output:** Plot both for the distribution of heads in 20 fair tosses.

# %% [markdown]
# ## 9) Add a vertical line + compute tail area (simulation + `pbinom`)
#
# Let \(X\) be # of heads in 20 fair tosses and set the cutoff at `x = 15`.
#
# **Desired output:**
# 1. Add a dashed vertical line at 15 on the same style plot.
# 2. Compute the simulated right-tail area by summing simulated proportions for `heads >= 15`.
# 3. Confirm with `pbinom(14, ..., lower.tail = FALSE)`.

# %% [markdown]
# ## 10) Bayes’ Rule (PPV) via simulation
#
# A screening test has:
# - prevalence $P(D) = 1/800$
# - sensitivity $P(T^+\mid D)=0.980$
# - specificity $P(T^-\mid D^c)=0.995$
#
# **Desired output:** Compute $P(D \mid T^+)$ via estimating from a simulation and by Bayes’ rule formula.

# %% [markdown]
# ## 11) Sampling distribution picture (pre–exact binomial test intuition)
#
# Observe `x_obs = 15` heads out of `n = 20`.
#
# **Desired output:** Plot the probability of `x=0,....,20` heads assuming a fair coin as bars (using `dbinom`) and add a vertical line at 15. Compute the right-tail probability with `pbinom`.

# %% [markdown]
# ---
# Reflection:
# 1. What parts of this lab were the hardest for you?
# 2. Do you still have questions on any of the problems?  If so, what are they?

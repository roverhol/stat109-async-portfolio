# %% [markdown]
# # Module 2 — Exercise lab (student)
#
# **Submit in Canvas** · Work all five problems after the [demo lab](module-2-lab-demo).
#
# Use plain code (no instructor color markup). Check conditions before each CI. Connect each problem to [Project 2](../projects/project-2) formula choices.
#
# **Practice bank:** [Synthesis quiz](../quizzes/quiz-m2-synthesis) Section G mirrors these situations.

# %% [markdown]
# ## Problem 1 — Mean, no FPC
#
# Random sample $n=25$ minutes/day from a large population.
#
# 1. Identify parameter and interval type.
# 2. Compute $\bar{x}$ and $s$; histogram + dot plot.
# 3. 95% CI (by hand or `t.test()`).

# %%
# Your code

# %% [markdown]
# ## Problem 2 — Mean with FPC
#
# $N=300$ classrooms; SRS $n=30$ without replacement.
#
# 1. Why use FPC?
# 2. Graph, summaries, 95% CI with FPC factor.

# %%
# Your code

# %% [markdown]
# ## Problem 3 — Proportion, no FPC
#
# $n=220$, $x=80$ with part-time job.
#
# 1. Report $\hat{p}$ and check large-count conditions.
# 2. Bar plot + 95% CI (`prop.test` or Wald formula).

# %%
# Your code

# %% [markdown]
# ## Problem 4 — Proportion with FPC
#
# $N=1500$, $n=108$, $x=20$ schools older than 50 years.
#
# 1. Apply FPC to the proportion SE.
# 2. Bar plot + 95% CI.

# %%
# Your code

# %% [markdown]
# ## Problem 5 — Small-sample proportion
#
# $n=10$, $x=3$ offer AP Stats.
#
# 1. Show large-count condition fails.
# 2. Use `binom.test()` for exact 95% CI.

# %%
# Your code

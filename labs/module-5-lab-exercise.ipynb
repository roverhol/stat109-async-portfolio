# %% [markdown]
# # Module 5 — Exercise lab (student)
#
# **Submit in Canvas** · Work all five problems after the [demo lab](module-5-lab-demo).
#
# Use plain code (no instructor color markup). Check conditions before each interval. Connect each problem to [Project 5](../projects/project-5) formula choices.
#
# **Practice bank:** [Synthesis quiz](../quizzes/quiz-m5-synthesis) Section E mirrors these situations.

# %% [markdown]
# ## About this exercise
#
# Work through all five problems after the [demo lab](module-5-lab-demo).
# Use **your team's Project 5 dataset** or the simulated stones data below.
# Submit your completed notebook in Canvas.
#
# **Practice bank:** [Synthesis quiz](../quizzes/quiz-m5-synthesis) Section E mirrors these situations.

# %% [markdown]
# ## Setup
#
# ```{r}
# if (!requireNamespace("tidyverse", quietly = TRUE)) {
#   install.packages("tidyverse", repos = "https://cloud.r-project.org")
# }
# library(tidyverse)
# ```

# %% [markdown]
# ## Your data
#
# Replace this simulated dataset with your team's actual Project 5 data (nesting dolls or stones).
# Variable names should match your team's chosen predictor and response.
#
# ```{r}
# # Replace with: dat <- read_csv("your-team-data.csv")
# set.seed(5002)
# n <- 22
# dat <- tibble(
#   width_cm   = runif(n, 4, 20),
#   weight_g   = 10 + 9.2 * width_cm + rnorm(n, 0, 12)
# )
#
# head(dat)
# ```

# %% [markdown]
# ### Problem 1 — Scatterplot and correlation
#
# Make a scatterplot of your response vs predictor and compute Pearson correlation. Describe form, direction, and strength.

# %%
# Your code here

# %% [markdown]
# ### Problem 2 — Fit lm() and interpret
#
# Fit a simple linear regression. Write the prediction equation and interpret the slope in context.

# %%
# Your code here

# %% [markdown]
# ### Problem 3 — Point prediction
#
# Predict the response for a new predictor value of your choice. Show the R call and the by-hand calculation.

# %%
# Your code here

# %% [markdown]
# ### Problem 4 — CI for slope
#
# Compute a 95% CI for the slope. Interpret in context. Does the CI include 0?

# %%
# Your code here

# %% [markdown]
# ### Problem 5 — CI for mean response vs prediction interval
#
# For one new predictor value, compute both intervals. Compare widths and write one sentence interpreting each.

# %%
# Your code here

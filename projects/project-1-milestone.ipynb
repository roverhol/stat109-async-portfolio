# %% [markdown]
# # Project 1 — Milestone notebook
#
# **Phase A** of [Project 1](project-1) with a more detailed description here, [project-1-milestone](project-1-milestone).

# %% [markdown]
# ## A1 — Choose your binomial process ($n = 25$)
#
# Describe the infinite process you will study (not a class example). Eventually you will observe at least $n = 25$ trials from this process in Phase B.
#
# Check all four BRP conditions in the context of your study:
#
# - **(a)** Binary outcome on each trial (success / failure)
# - **(b)** Independent trials
# - **(c)** Fixed $p$ on each trial
# - **(d)** Fixed $n$ (you will use $n = 25$)
#
# **My process** *(a few sentences):*
#
# ```
# [ your answer ]
# ```
#
# **Why each BRP condition holds** *(brief, in context):*
#
# ```
# (a) ...
# (b) ...
# (c) ...
# (d) ...
# ```

# %% [markdown]
# ## A2 — Research question
#
# Write your research question. Include your best guess about the size of $p$ in the infinite process.
#
# **My research question** *(one or two sentences, with your guess about $p$):*
#
# ```
# [ your answer ]
# ```

# %% [markdown]
# ## A3 — Define $p$ in context
#
# $p$ is the probability of one success in one trial. State what counts as one "success" for your study and give a one sentence description of $p$ in this context:
#
# **$p$ in context** *(one sentence):*
#
# ```
# [ your answer ]
# ```

# %% [markdown]
# ## A4 — Null and alternative hypotheses
#
# State $H_0$ and $H_a$ with a numeric $p$ where $0 < p < 1$ from your best guess. Write $H_a$ by translating your research question into our notation ($p > \ldots$, $p < \ldots$, or $p \neq \ldots$).
#
# $H_0$: $p$ = ___
#
# $H_a$: $p$ ___ (choose $>$, $<$, or $\neq$) ___

# %% [markdown]
# ## A5 — Null binomial graph in R
#
# Use $n = 25$ (or the number of trials you are planning to collect data from) and $p$ from **$H_0$**. Plot $P(X = x)$ with `dbinom()` + `geom_col()`.
#
# **Do not** mark an observed $x$ or compute a p-value yet — that is Phase B.
#
# Help: [Module 1 demo lab](../labs/module-1-lab-demo) · [R reference](../r-reference)
#
# ```
# n = 25
# p =   # from H_0
# ```

# %% [markdown]
# ### Your R code (null plot only)

# %%
# Your code here — dbinom + geom_col, no geom_vline yet

# %% [markdown]
# ## Submit in Canvas
#
# 1. **A1** — Process + four BRP conditions in context
# 2. **A2** — Research question + guess about $p$
# 3. **A3** — What counts as success / $p$ in one sentence
# 4. **A4** — $H_0$ and $H_a$ with numeric $p$
# 5. **A5** — Null binomial graph (no $x$, no p-value)

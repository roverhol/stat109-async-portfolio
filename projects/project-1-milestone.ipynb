# %% [markdown]
# # Project 1 — Milestone / precheck notebook
#
# **Phase A of [Project 1](project-1)** · Hub page: [project-1-milestone](project-1-milestone)
#
# Plan your study **before** collecting all $n = 25$ trials: research question, $p$ in context, $H_0$/$H_a$, and **null binomial graph** ($p$ from $H_0$ only — no observed $x$ yet).
#
# **Submit:** Canvas **milestone** assignment (see [Module 1 schedule](../schedule#module-1--testing-a-claim-jun-17)).
#
# **After milestone:** Collect data and complete **Phase B** on the [Project 1 page](project-1) (full report rubric).
#
# **Do not** use class examples (coin tosses, ESP, etc.) as your study.

# %% [markdown]
# ## Step 1: Your research question
#
# From Project 1, choose a **Binomial Random Process** with $n = 25$ trials and all four BRP conditions.
#
# **My research question** *(one or two sentences):*
#
# ```
# [ your answer ]
# ```

# %% [markdown]
# ## Step 2: What is $p$ in your context?
#
# $p$ = probability of a **success on one trial**. Define "success" for your study.
#
# **$p$ in context** *(one sentence):*
#
# ```
# [ your answer ]
# ```

# %% [markdown]
# ## Step 3: Null and alternative hypotheses
#
# $H_0$: $p$ = ___
#
# $H_a$: $p$ ___ (choose $>$, $<$, or $\neq$) ___

# %% [markdown]
# ## Step 4: Values of $n$ and $p$ for R
#
# ```
# n = 25
# p =
# ```

# %% [markdown]
# ## Step 5: Create your binomial graph in R
#
# 1. Use [Module 1 demo Section C](../labs/module-1-lab-demo) or [R reference](../r-reference).
# 2. Plot $P(X = x)$ with `dbinom()` + `geom_col()`.
# 3. Export for Canvas.
#
# ```{r}
# #| eval: false
# # Your code here
# ```

# %% [markdown]
# ## What to turn in (Canvas milestone)
#
# 1. Research question · 2. What $p$ means · 3. $H_0$ and $H_a$ · 4. Null binomial graph
